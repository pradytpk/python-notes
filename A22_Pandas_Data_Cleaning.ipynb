# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dates = pd.date_range("20130101",periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6,4),index=dates,columns=list("ABCD"))

# %%
d=pd.Series(np.random.rand(1000))

# %%
d.hist()
# Out:
# <Axes: >

# %%
d=pd.Series(np.random.randn(1000))

# %%
d.hist()
# Out:
# <Axes: >

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.533361  0.119348  0.221222  0.909427
# 2013-01-02  0.146442  0.340805  0.919193  0.745731
# 2013-01-03  0.149764  0.408739  0.888402  0.008321
# 2013-01-04  0.461651  0.475978  0.764275  0.095942
# 2013-01-05  0.564692  0.774431  0.682277  0.379098
# 2013-01-06  0.815385  0.600901  0.382557  0.783892

# %%
sns.distplot(d)
# Out:
# C:\Users\thang\AppData\Local\Temp\ipykernel_17044\1758541930.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d)
# <Axes: ylabel='Density'>

# %%
df1 = pd.DataFrame(
{
    "A":["A0","A1","A2","A3"],
    "B":["A0","A1","A2","A3"],
    "C":["A0","A1","A2","A3"],
    "D":["A0","A1","A2","A3"],
},index=[0,1,2,3]
)

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3

# %%
df2 = pd.DataFrame(
{
    "A":["A0","A1","A2","A3"],
    "B":["A0","A1","A2","A3"],
    "C":["A0","A1","A2","A3"],
    "D":["A0","A1","A2","A3"],
},index=[0,1,2,3]
)

# %%
df3 = pd.DataFrame(
{
    "A":["A0","A1","A2","A3"],
    "B":["A0","A1","A2","A3"],
    "C":["A0","A1","A2","A3"],
    "D":["A0","A1","A2","A3"],
},index=[0,1,2,3]
)

# %%
frames=[df1,df2,df3]

# %%
result=pd.concat(frames)

# %%
result
# Out:
#     A   B   C   D
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3

# %%
s = pd.Series(['1','2000','3000'])

# %%
s
# Out:
# 0       1
# 1    2000
# 2    3000
# dtype: object

# %%
s1=pd.to_numeric(s)

# %%
s1
# Out:
# 0       1
# 1    2000
# 2    3000
# dtype: int64

# %%
s2=pd.Series(['1','#Apple','3000'])

# %%
s2
# Out:
# 0         1
# 1    #Apple
# 2      3000
# dtype: object

# %%
s2=pd.to_numeric(s2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "#Apple"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 s2=pd.to_numeric(s2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "#Apple" at position 1

# %%
a = pd.to_numeric(s2,errors='coerce')

# %%
a
# Out:
# 0       1.0
# 1       NaN
# 2    3000.0
# dtype: float64

# %%
a=a.dropna(axis=0)

# %%
a
# Out:
# 0       1.0
# 2    3000.0
# dtype: float64

# %%
s3=pd.Series(['1','#Apple','3000'])

# %%
s3
# Out:
# 0         1
# 1    #Apple
# 2      3000
# dtype: object
