# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
dates = pd.date_range("20130101",periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2013-01-01', '2013-01-02', '2013-01-03', '2013-01-04',
#                '2013-01-05', '2013-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.rand(6,4),index=dates,columns=list("ABCD"))

# %%
d=pd.Series(np.random.rand(1000))

# %%
d.hist()
# Out:
# <Axes: >

# %%
d=pd.Series(np.random.randn(1000))

# %%
d.hist()
# Out:
# <Axes: >

# %%
df
# Out:
#                    A         B         C         D
# 2013-01-01  0.583180  0.648667  0.590071  0.419549
# 2013-01-02  0.519889  0.545240  0.100265  0.221649
# 2013-01-03  0.343869  0.680747  0.212689  0.617768
# 2013-01-04  0.070593  0.591529  0.120749  0.011643
# 2013-01-05  0.361892  0.976546  0.568151  0.168677
# 2013-01-06  0.334888  0.913535  0.891886  0.655988

# %%
sns.distplot(d)
# Out:
# C:\Users\thang\AppData\Local\Temp\ipykernel_14240\1758541930.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(d)
# <Axes: ylabel='Density'>

# %%
df1 = pd.DataFrame(
{
    "A":["A0","A1","A2","A3"],
    "B":["A0","A1","A2","A3"],
    "C":["A0","A1","A2","A3"],
    "D":["A0","A1","A2","A3"],
},index=[0,1,2,3]
)

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3

# %%
df2 = pd.DataFrame(
{
    "A":["A0","A1","A2","A3"],
    "B":["A0","A1","A2","A3"],
    "C":["A0","A1","A2","A3"],
    "D":["A0","A1","A2","A3"],
},index=[0,1,2,3]
)

# %%
df3 = pd.DataFrame(
{
    "A":["A0","A1","A2","A3"],
    "B":["A0","A1","A2","A3"],
    "C":["A0","A1","A2","A3"],
    "D":["A0","A1","A2","A3"],
},index=[0,1,2,3]
)

# %%
frames=[df1,df2,df3]

# %%
result=pd.concat(frames)

# %%
result
# Out:
#     A   B   C   D
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3
# 0  A0  A0  A0  A0
# 1  A1  A1  A1  A1
# 2  A2  A2  A2  A2
# 3  A3  A3  A3  A3

# %%
s = pd.Series(['1','2000','3000'])

# %%
s
# Out:
# 0       1
# 1    2000
# 2    3000
# dtype: object

# %%
s1=pd.to_numeric(s)

# %%
s1
# Out:
# 0       1
# 1    2000
# 2    3000
# dtype: int64

# %%
s2=pd.Series(['1','#Apple','3000'])

# %%
s2
# Out:
# 0         1
# 1    #Apple
# 2      3000
# dtype: object

# %%
s2=pd.to_numeric(s2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2280, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "#Apple"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 s2=pd.to_numeric(s2)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\tools\numeric.py:217, in to_numeric(arg, errors, downcast, dtype_backend)
#     215 coerce_numeric = errors not in ("ignore", "raise")
#     216 try:
# --> 217     values, new_mask = lib.maybe_convert_numeric(  # type: ignore[call-overload]  # noqa
#     218         values,
#     219         set(),
#     220         coerce_numeric=coerce_numeric,
#     221         convert_to_masked_nullable=dtype_backend is not lib.no_default
#     222         or isinstance(values_dtype, StringDtype),
#     223     )
#     224 except (ValueError, TypeError):
#     225     if errors == "raise":
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\lib.pyx:2322, in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "#Apple" at position 1

# %%
a = pd.to_numeric(s2,errors='coerce')

# %%
a
# Out:
# 0       1.0
# 1       NaN
# 2    3000.0
# dtype: float64

# %%
a=a.dropna(axis=0)

# %%
a
# Out:
# 0       1.0
# 2    3000.0
# dtype: float64

# %%
s3=pd.Series(['1','#Apple','3000'])

# %%
s3
# Out:
# 0         1
# 1    #Apple
# 2      3000
# dtype: object

# %%
de = {'training':['DA','ML','DL','AI',np.nan], 'hours':[np.nan,np.nan,5,6,np.nan], 'tools':[np.nan,np.nan,np.nan,4,np.nan]}

# %%
df1 = pd.DataFrame(de)

# %%
df1
# Out:
#   training  hours  tools
# 0       DA    NaN    NaN
# 1       ML    NaN    NaN
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0
# 4      NaN    NaN    NaN

# %%
df1.shape
# Out:
# (5, 3)

# %%
df1.info
# Out:
# <bound method DataFrame.info of   training  hours  tools
# 0       DA    NaN    NaN
# 1       ML    NaN    NaN
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0
# 4      NaN    NaN    NaN>

# %%
df1.isnull().sum()
# Out:
# training    1
# hours       3
# tools       4
# dtype: int64

# %%
df1
# Out:
#   training  hours  tools
# 0       DA    NaN    NaN
# 1       ML    NaN    NaN
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0
# 4      NaN    NaN    NaN

# %%
df1.dropna(axis=0)
# Out:
#   training  hours  tools
# 3       AI    6.0    4.0

# %%
df1
# Out:
#   training  hours  tools
# 0       DA    NaN    NaN
# 1       ML    NaN    NaN
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0
# 4      NaN    NaN    NaN

# %%
df1.dropna(axis=1)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
df1
# Out:
#   training  hours  tools
# 0       DA    NaN    NaN
# 1       ML    NaN    NaN
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0
# 4      NaN    NaN    NaN

# %%
df1.dropna(subset = ['hours'])
# Out:
#   training  hours  tools
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0

# %%
df1.dropna(thresh =2)
# Out:
#   training  hours  tools
# 2       DL    5.0    NaN
# 3       AI    6.0    4.0

# %%
df1.fillna(100)
# Out:
#   training  hours  tools
# 0       DA  100.0  100.0
# 1       ML  100.0  100.0
# 2       DL    5.0  100.0
# 3       AI    6.0    4.0
# 4      100  100.0  100.0

# %%
df1.fillna(df1.mean(numeric_only=True))
# Out:
#   training  hours  tools
# 0       DA    5.5    4.0
# 1       ML    5.5    4.0
# 2       DL    5.0    4.0
# 3       AI    6.0    4.0
# 4      NaN    5.5    4.0

# %%
df1.replace(4, 'four')
# Out:
#   training  hours tools
# 0       DA    NaN   NaN
# 1       ML    NaN   NaN
# 2       DL    5.0   NaN
# 3       AI    6.0  four
# 4      NaN    NaN   NaN

# %%
df1.replace([5,6], '12#WhEREisMyAssignMent??')
# Out:
#   training                     hours  tools
# 0       DA                       NaN    NaN
# 1       ML                       NaN    NaN
# 2       DL  12#WhEREisMyAssignMent??    NaN
# 3       AI  12#WhEREisMyAssignMent??    4.0
# 4      NaN                       NaN    NaN

# %%
df1.replace([5,6],[222, 442])
# Out:
#   training  hours  tools
# 0       DA    NaN    NaN
# 1       ML    NaN    NaN
# 2       DL  222.0    NaN
# 3       AI  442.0    4.0
# 4      NaN    NaN    NaN

# %%
df1.iloc[1,2] = '1@&34EsRj2'

# %%
df1.iloc[2,2] = 'h&!}+1FRe3'

# %%
df1
# Out:
#   training  hours       tools
# 0       DA    NaN         NaN
# 1       ML    NaN  1@&34EsRj2
# 2       DL    5.0  h&!}+1FRe3
# 3       AI    6.0         4.0
# 4      NaN    NaN         NaN

# %%
df1.replace(regex = True, to_replace = '[^0-9]', value = '')
# Out:
#   training  hours tools
# 0             NaN   NaN
# 1             NaN  1342
# 2             5.0    13
# 3             6.0   4.0
# 4      NaN    NaN   NaN

# %%
df1.iloc[:,1:3] = df1.iloc[:,1:3].replace(regex= True, to_replace = '[^0-9]', value = '')

# %%
df1.iloc[:,1:3]
# Out:
#    hours tools
# 0    NaN   NaN
# 1    NaN  1342
# 2    5.0    13
# 3    6.0   4.0
# 4    NaN   NaN
