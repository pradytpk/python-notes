# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Case-Study-1" data-toc-modified-id="Case-Study-1-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Case Study-1</a></span><ul class="toc-item"><li><span><a href="#Task-1:-Number-of-Hurricanes-Bar-Graph" data-toc-modified-id="Task-1:-Number-of-Hurricanes-Bar-Graph-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Task 1: Number of Hurricanes Bar Graph</a></span></li><li><span><a href="#Task-2:-Temperature-Histogram-for-San-Francisco-and-Moscow" data-toc-modified-id="Task-2:-Temperature-Histogram-for-San-Francisco-and-Moscow-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Task 2: Temperature Histogram for San Francisco and Moscow</a></span></li><li><span><a href="#Task-3:-Pie-Chart-for-Number-of-Models-by-Manufacturer" data-toc-modified-id="Task-3:-Pie-Chart-for-Number-of-Models-by-Manufacturer-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Task 3: Pie Chart for Number of Models by Manufacturer</a></span></li><li><span><a href="#Task-4:-Create-and-Read-CSV-File-to-Pandas-DataFrame" data-toc-modified-id="Task-4:-Create-and-Read-CSV-File-to-Pandas-DataFrame-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Task 4: Create and Read CSV File to Pandas DataFrame</a></span></li><li><span><a href="#Let-the-x-axisdata-points-and-y-axis-data-points-are" data-toc-modified-id="Let-the-x-axisdata-points-and-y-axis-data-points-are-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Let the x-axisdata points and y-axis data points are</a></span></li><li><span><a href="#Case-Study" data-toc-modified-id="Case-Study-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Case Study</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Case Study-1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Assuming you have a dataset named 'hurricanes.csv'
data = pd.read_csv('C:\Study\Data Science\Datasets\Hurricanes.csv')
data
# Out:
#      Year  Hurricanes
# 0    1914           0
# 1    1915           5
# 2    1916          10
# 3    1917           2
# 4    1918           4
# ..    ...         ...
# 96   2010          12
# 97   2011           7
# 98   2012          10
# 99   2013           2
# 100  2014           6
#
# [101 rows x 2 columns]

# %% [markdown]
# ## Task 1: Number of Hurricanes Bar Graph

# %%
# Plot a bar graph
plt.figure(figsize=(10, 6))
plt.bar(data['Year'], data['Hurricanes'])
plt.xlabel('Year')
plt.ylabel('Number of Hurricanes')
plt.title('Number of Hurricanes in the United States (Atlantic Coast)')
plt.show()

# %% [markdown]
# ## Task 2: Temperature Histogram for San Francisco and Moscow

# %%
# Assuming you have a DataFrame named 'temperature_data'
temperature_data = pd.read_csv('C:\Study\Data Science\Datasets\CityTemps.csv')
# You can filter the data for San Francisco and Moscow and plot their histograms
sf_temperatures = temperature_data['San Francisco']
moscow_temperatures = temperature_data['Moscow'] 

plt.hist(sf_temperatures, bins=20, alpha=0.5, label='San Francisco')
plt.hist(moscow_temperatures, bins=20, alpha=0.5, label='Moscow')
plt.xlabel('Temperature')
plt.ylabel('Frequency')
plt.legend()
plt.title('Temperature Histogram for San Francisco and Moscow')
plt.show()

# %% [markdown]
# ## Task 3: Pie Chart for Number of Models by Manufacturer

# %%
car_data = pd.read_csv('C:\Study\Data Science\Datasets\data_file.txt')
car_data
# Out:
#      account_number                           name item_code category  \
# 0            296809                    Carroll PLC  QN-82852     Belt
# 1             98022              Heidenreich-Bosco  MJ-21460    Shoes
# 2            563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt
# 3             93356                  Waters-Walker  AS-93055    Shirt
# 4            659366                  Waelchi-Fahey  AS-93055    Shirt
# ..              ...                            ...       ...      ...
# 995          758133      Kihn, McClure and Denesik  WJ-02096     Belt
# 996          850140                      Kunze Inc  GS-86623    Shoes
# 997           93356                  Waters-Walker  GS-86623    Shoes
# 998          304860                      Huel-Haag  LL-46261    Shoes
# 999           98022              Heidenreich-Bosco  LW-86841    Shoes
#
#      quantity  unit price  net_price                 date
# 0          13       44.48     578.24  2014-09-27 07:13:03
# ...

# %%
# Assuming you have a DataFrame named 'car_data'
# You can group the data by manufacturer and count the number of models
manufacturer_counts = car_data['name'].value_counts()

# Plot a pie chart
plt.figure(figsize=(8, 8))
plt.pie(manufacturer_counts, labels=manufacturer_counts.index, autopct='%1.1f%%')
plt.title('Number of Models by Manufacturer')
plt.show()

# Find the manufacturer with the largest releases
largest_manufacturer = manufacturer_counts.idxmax()
print(f"The manufacturer with the largest releases is: {largest_manufacturer}")
# Out:
# The manufacturer with the largest releases is: Senger, Upton and Breitenberg

# %% [markdown]
# ## Task 4: Create and Read CSV File to Pandas DataFrame

# %%
df = pd.read_csv('C:\Study\Data Science\Datasets\sample-salesv2.csv')
df.head()
# Out:
#    account_number                           name item_code category  quantity  \
# 0          296809                    Carroll PLC  QN-82852     Belt        13
# 1           98022              Heidenreich-Bosco  MJ-21460    Shoes        19
# 2          563905  Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12
# 3           93356                  Waters-Walker  AS-93055    Shirt         5
# 4          659366                  Waelchi-Fahey  AS-93055    Shirt        18
#
#    unit price  net_price              date
# 0       44.48     578.24  27-09-2014 07:13
# 1       53.62    1018.78  29-07-2014 02:10
# 2       24.16     289.92  01-03-2014 10:51
# 3       82.68     413.40  17-11-2013 20:41
# 4       99.64    1793.52  03-01-2014 08:14

# %%
df.columns
# Out:
# Index(['account_number', 'name', 'item_code', 'category', 'quantity',
#        'unit price', 'net_price', 'date'],
#       dtype='object')

# %%
# Save the DataFrame to a CSV file
df = pd.read_csv('C:\Study\Data Science\Datasets\sample-salesv2.csv')

# Phase 2: Describe the data on the unit_price
unit_price_description = df['unit price'].describe()
print("Unit Price Description:")
print(unit_price_description)

# Phase 3: Filter the data and group by name
filtered_df = df[['name', 'net_price', 'date']].groupby('name').sum().reset_index()

# Phase 4: Plotting graph
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.bar(filtered_df['name'], filtered_df['net_price'])
plt.xlabel('Customer Name')
plt.ylabel('Total Sales')
plt.title('Total Sales by Customer')
plt.xticks(rotation=45)
plt.show()
# Out:
# Unit Price Description:
# count    1000.000000
# mean       56.179630
# std        25.331939
# min        10.060000
# 25%        35.995000
# 50%        56.765000
# 75%        76.802500
# max        99.970000
# Name: unit price, dtype: float64

# %% [markdown]
# ## Let the x-axisdata points and y-axis data points are
#
# X = [1,2,3,4]y = [20, 21, 20.5, 20.8]
# - 5.1: Draw a Simple plot
# - 5.2: Configure the line and markers in a simple plot
# - 5.3: configure the axes
# - 5.4: Give the title of the graph andlabels of the x-axis and y-axis
# - 5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
# - 5.6: define width, and height as figsize=(4,5) DPI and adjust plot dpi=100
# - 5.7: Give a font size of 14
# - 5.8: Draw a scatter graph of any 50 random values of the x and y-axis
# - 5.9: Create a dataframe from the following data'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'], 'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'], 'female': [0, 1, 1, 0, 1],'age': [42, 52, 36, 24, 73], 'preTestScore': [4, 24, 31, 2, 3],'postTestScore': [25, 94, 57, 62, 70]
# - Draw a Scatterplot of preTestScore and postTestScore, with the size of each point determined by age.
# - 5.10: Draw a Scatterplot from the data in question 9 of preTestScore and postTestScore with the size = 300 and the color determined by sex

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Task 5.1: Draw a Simple plot
X = [1, 2, 3, 4]
y = [20, 21, 20.5, 20.8]
plt.figure(figsize=(8, 4))
plt.plot(X, y)
plt.title('Simple Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Task 5.2: Configure the line and markers in a simple plot
plt.figure(figsize=(8, 4))
plt.plot(X, y, linestyle='--', marker='o', color='b')
plt.title('Line and Markers Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Task 5.3: Configure the axes
plt.figure(figsize=(8, 4))
plt.plot(X, y, linestyle='-', marker='o', color='g')
plt.title('Configured Axes Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.xlim(0, 5)
plt.ylim(19, 22)
plt.show()

# %%
# Task 5.4: Give the title of the graph and labels of the x-axis and y-axis
plt.figure(figsize=(8, 4))
plt.plot(X, y, linestyle='-', marker='o', color='r')
plt.title('Customized Plot')
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.show()

# %%
# Task 5.5: Give error bar if y_error = [0.12, 0.13, 0.2, 0.1]
y_error = [0.12, 0.13, 0.2, 0.1]
plt.figure(figsize=(8, 4))
plt.errorbar(X, y, yerr=y_error, linestyle='-', marker='o', color='purple')
plt.title('Error Bar Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Task 5.6: Define width, height, and DPI
plt.figure(figsize=(4, 5), dpi=100)
plt.plot(X, y, linestyle='-', marker='o', color='orange')
plt.title('Custom Size and DPI Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Task 5.7: Give a font size of 14
plt.figure(figsize=(8, 4))
plt.plot(X, y, linestyle='-', marker='o', color='b')
plt.title('Custom Font Size Plot', fontsize=14)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Task 5.8: Draw a scatter graph of 50 random values of x and y-axis
x_random = np.random.rand(50)
y_random = np.random.rand(50)
plt.figure(figsize=(8, 4))
plt.scatter(x_random, y_random, marker='o', color='green')
plt.title('Scatter Plot of Random Values')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.show()

# %%
# Task 5.9: Create a DataFrame from the given data
data = {
    'first_name': ['Jason', 'Molly', 'Tina', 'Jake', 'Amy'],
    'last_name': ['Miller', 'Jacobson', 'Ali', 'Milner', 'Cooze'],
    'female': [0, 1, 1, 0, 1],
    'age': [42, 52, 36, 24, 73],
    'preTestScore': [4, 24, 31, 2, 3],
    'postTestScore': [25, 94, 57, 62, 70]
}

# %%
df = pd.DataFrame(data)

# Scatterplot of preTestScore and postTestScore with size determined by age
plt.figure(figsize=(8, 4))
plt.scatter(df['preTestScore'], df['postTestScore'], s=df['age'], alpha=0.5)
plt.title('Scatter Plot with Size by Age')
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.show()

# %%
# Task 5.10: Scatterplot with size = 300 and color determined by sex
colors = df['female'].map({0: 'blue', 1: 'pink'})
plt.figure(figsize=(8, 4))
plt.scatter(df['preTestScore'], df['postTestScore'], s=300, c=colors, alpha=0.7)
plt.title('Scatter Plot with Custom Size and Color')
plt.xlabel('preTestScore')
plt.ylabel('postTestScore')
plt.show()

# %% [markdown]
# ## Case Study

# %%
# Read CSV files
df_math_scores = pd.read_csv("C:\Study\Data Science\Datasets\MathScoreTerm1.csv")
df_ds_score = pd.read_csv("C:\Study\Data Science\Datasets\DSScoreTerm1.csv")
df_physics_score = pd.read_csv("C:\Study\Data Science\Datasets\PhysicsScoreTerm1.csv")

# %%
# Remove columns
del df_math_scores["Name"]
del df_math_scores["Ethinicity"]

del df_ds_score["Name"]
del df_ds_score["Ethinicity"]

del df_physics_score["Name"]
del df_physics_score["Ethinicity"]

# %%
# Fill missing values with zeros
df_math_scores.fillna(0, inplace=True)
df_ds_score.fillna(0, inplace=True)
df_physics_score.fillna(0, inplace=True)

# %%
# Merge DataFrames
merged_df = df_math_scores.merge(df_ds_score, on="ID", suffixes=('_math', '_ds')).merge(df_physics_score, on="ID", suffixes=('_ds', '_phys'))

# %%
# Update Sex column
sex_mapping = {"M": 1, "F": 2}
merged_df["Sex"] = merged_df["Sex"].map(sex_mapping)

# %%
# Save cleaned data
merged_df.to_csv("ScoreFinal.csv")
