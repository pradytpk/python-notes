# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
heart = pd.read_csv('C:\Study\Data Science\Datasets\clevelanda.csv')

# %%
heart.head()
# Out:
#    age  gender  cp  trestbps  chol  fps  restecg  thalach  exang  oldpeak  \
# 0   63       1   1       145   233    1        2      150      0      2.3
# 1   67       1   4       160   286    0        2      108      1      1.5
# 2   67       1   4       120   229    0        2      129      1      2.6
# 3   37       1   3       130   250    0        0      187      0      3.5
# 4   41       0   2       130   204    0        2      172      0      1.4
#
#    slope ca thal  class
# 0      3  0    6      0
# 1      2  3    3      2
# 2      2  2    7      1
# 3      3  0    3      0
# 4      1  0    3      0

# %%
heart['age'].hist()
# Out:
# <Axes: >

# %%
heart.shape
# Out:
# (303, 14)

# %%
sns.lineplot(x = heart['age'], y = heart['thalach'])
# Out:
# <Axes: xlabel='age', ylabel='thalach'>

# %%
sns.lineplot(x = heart['age'], y = heart['trestbps'])
# Out:
# <Axes: xlabel='age', ylabel='trestbps'>

# %%
sns.scatterplot(x = heart['chol'], y = heart['trestbps'])
# Out:
# <Axes: xlabel='chol', ylabel='trestbps'>

# %%
heart.corr(numeric_only=True)
# Out:
#                age    gender        cp  trestbps      chol       fps  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# gender   -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fps       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# class     0.222853  0.224469  0.407075  0.157754  0.070909  0.059186
#
#            restecg   thalach     exang   oldpeak     slope     class
# ...

# %%
sns.lineplot(x = heart['age'], y= heart['thalach'])
plt.title('Trend Analysis on Max Heart Rate')
plt.ylabel('Max Heart Rate')
plt.xlabel('Age of pat')
plt.show()

# %%
df = pd.DataFrame(np.random.rand(10,4), columns = ['a','b','c','d'])

# %%
sns.pairplot(df)
# Out:
# C:\Users\thang\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
d = heart.corr(numeric_only=True)

# %%
d
# Out:
#                age    gender        cp  trestbps      chol       fps  \
# age       1.000000 -0.097542  0.104139  0.284946  0.208950  0.118530
# gender   -0.097542  1.000000  0.010084 -0.064456 -0.199915  0.047862
# cp        0.104139  0.010084  1.000000 -0.036077  0.072319 -0.039975
# trestbps  0.284946 -0.064456 -0.036077  1.000000  0.130120  0.175340
# chol      0.208950 -0.199915  0.072319  0.130120  1.000000  0.009841
# fps       0.118530  0.047862 -0.039975  0.175340  0.009841  1.000000
# restecg   0.148868  0.021647  0.067505  0.146560  0.171043  0.069564
# thalach  -0.393806 -0.048663 -0.334422 -0.045351 -0.003432 -0.007854
# exang     0.091661  0.146201  0.384060  0.064762  0.061310  0.025665
# oldpeak   0.203805  0.102173  0.202277  0.189171  0.046564  0.005747
# slope     0.161770  0.037533  0.152050  0.117382 -0.004062  0.059894
# class     0.222853  0.224469  0.407075  0.157754  0.070909  0.059186
#
#            restecg   thalach     exang   oldpeak     slope     class
# ...

# %%
plt.figure(figsize = (10,10))
sns.heatmap(d, annot=True)
# Out:
# <Axes: >

# %%
df1 = np.random.randn(100000)
df2 = np.random.rand(100000)

# %%
sns.distplot(df1, hist = False)
# Out:
# C:\Users\thang\AppData\Local\Temp\ipykernel_16348\184260116.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1, hist = False)
# <Axes: ylabel='Density'>

# %%
sns.distplot(heart['age'])
# Out:
# C:\Users\thang\AppData\Local\Temp\ipykernel_16348\3901112812.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
sns.countplot(x = 'gender', data = heart, hue = 'class')
plt.legend(loc = 'upper right')

# %%
sns.jointplot(x = heart['age'], y = heart['thalach'], color="#0000FF")

# %%
sns.scatterplot(x = 'age', y= 'thalach', data = heart, hue = 'gender')
# plt.savefig('dec_2022.png')
# Out:
# <Axes: xlabel='age', ylabel='thalach'>

# %%
sns.lmplot(x = 'age', y = 'thalach', data =heart, row = 'gender')
# Out:
# C:\Users\thang\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
penguins = sns.load_dataset("penguins")
sns.displot(penguins, x="flipper_length_mm")
# Out:
# C:\Users\thang\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(x = 'age', y = 'thalach', data =heart, col = 'gender')
# Out:
# C:\Users\thang\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
plt.figure(figsize = (14,14))
plt.subplot(221)
plt.title('Count of heart pat')
sns.countplot(heart['class'])


plt.subplot(222)
plt.title('Distribution of Age')
sns.distplot(heart['age'])

plt.subplot(223)
plt.title('Correlation between')
sns.scatterplot(heart['age'],heart['thalach'])

plt.subplot(224)
plt.title('Outlier Study')
sns.boxplot(x = heart['age'], y = heart['thalach'])
#plt.savefig('Dec_Anal.png')
# Out:
# C:\Users\thang\AppData\Local\Temp\ipykernel_16348\2335058948.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(heart['age'])
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 13
#      11 plt.subplot(223)
#      12 plt.title('Correlation between')
# ---> 13 sns.scatterplot(heart['age'],heart['thalach'])
#      15 plt.subplot(224)
#      16 plt.title('Outlier Study')
#
# TypeError: scatterplot() takes from 0 to 1 positional arguments but 2 were given

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="whitegrid")

# Load the example diamonds dataset
diamonds = sns.load_dataset("diamonds")

# Draw a scatter plot while assigning point colors and sizes to different
# variables in the dataset
f, ax = plt.subplots(figsize=(6.5, 6.5))
sns.despine(f, left=True, bottom=True)
clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]
sns.scatterplot(x="carat", y="price",
                hue="clarity", size="depth",
                palette="ch:r=-.2,d=.3_r",
                hue_order=clarity_ranking,
                sizes=(1, 8), linewidth=0,
                data=diamonds, ax=ax)
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %%
import numpy as np
import matplotlib.pyplot as plt


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 35, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]
men_std = [2, 3, 4, 1, 2]
women_std = [3, 5, 2, 3, 3]
width = 0.35       # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots()

ax.bar(labels, men_means, width, yerr=men_std, label='Men')
ax.bar(labels, women_means, width, yerr=women_std, bottom=men_means,
       label='Women')

ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.legend()

plt.show()

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

# Load the example tips dataset
tips = sns.load_dataset("tips")

# Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
            hue="smoker", palette=["m", "g"],
            data=tips)
sns.despine(offset=10, trim=True)

# %%
import seaborn as sns
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
fmri = sns.load_dataset("fmri")

# Plot the responses for different events and regions
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# <Axes: xlabel='timepoint', ylabel='signal'>
